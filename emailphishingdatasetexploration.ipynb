# %% [markdown]
# <a href="https://colab.research.google.com/github/karandomguy/Phishing-Email-Detection/blob/main/emailphishingdatasetexploration.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! pip install kaggle

# %%
! mkdir ~/.kaggle
# Out:
# mkdir: cannot create directory ‘/root/.kaggle’: File exists

# %%
! cp kaggle.json ~/.kaggle/

# %%
! chmod 600 ~/.kaggle/kaggle.json

# %%
# !kaggle datasets download -d subhajournal/phishingemails
# Out:
# phishingemails.zip: Skipping, found more recently modified local copy (use --force to force download)

# %%
import zipfile
import pandas as pd

# %%
df = pd.read_csv('phishingemails.zip',compression='zip')

# %%
df
# Out:
#        Unnamed: 0                                         Email Text  \
# 0               0  re : 6 . 1100 , disc : uniformitarianism , re ...
# 1               1  the other side of * galicismos * * galicismo *...
# 2               2  re : equistar deal tickets are you still avail...
# 3               3  \nHello I am your hot lil horny toy.\n    I am...
# 4               4  software at incredibly low prices ( 86 % lower...
# ...           ...                                                ...
# 18645       18646  date a lonely housewife always wanted to date ...
# 18646       18647  request submitted : access request for anita ....
# 18647       18648  re : important - prc mtg hi dorn & john , as y...
# 18648       18649  press clippings - letter on californian utilit...
# 18649       18650                                              empty
#
#            Email Type
# 0          Safe Email
# 1          Safe Email
# 2          Safe Email
# 3      Phishing Email
# ...

# %%
df.head()
# Out:
#    Unnamed: 0                                         Email Text  \
# 0           0  re : 6 . 1100 , disc : uniformitarianism , re ...
# 1           1  the other side of * galicismos * * galicismo *...
# 2           2  re : equistar deal tickets are you still avail...
# 3           3  \nHello I am your hot lil horny toy.\n    I am...
# 4           4  software at incredibly low prices ( 86 % lower...
#
#        Email Type
# 0      Safe Email
# 1      Safe Email
# 2      Safe Email
# 3  Phishing Email
# 4  Phishing Email

# %%
df['Email Text'][0]
# Out:
# 're : 6 . 1100 , disc : uniformitarianism , re : 1086 ; sex / lang dick hudson \'s observations on us use of \'s on \' but not \'d aughter \' as a vocative are very thought-provoking , but i am not sure that it is fair to attribute this to " sons " being " treated like senior relatives " . for one thing , we do n\'t normally use \' brother \' in this way any more than we do \'d aughter \' , and it is hard to imagine a natural class comprising senior relatives and \'s on \' but excluding \' brother \' . for another , there seem to me to be differences here . if i am not imagining a distinction that is not there , it seems to me that the senior relative terms are used in a wider variety of contexts , e . g . , calling out from a distance to get someone \'s attention , and hence at the beginning of an utterance , whereas \'s on \' seems more natural in utterances like \' yes , son \' , \' hand me that , son \' than in ones like \' son ! \' or \' son , help me ! \' ( although perhaps the
# ...

# %%
df['Email Text'][1]
# Out:
# 'the other side of * galicismos * * galicismo * is a spanish term which names the improper introduction of french words which are spanish sounding and thus very deceptive to the ear . * galicismo * is often considered to be a * barbarismo * . what would be the term which designates the opposite phenomenon , that is unlawful words of spanish origin which may have crept into french ? can someone provide examples ? thank you joseph m kozono < kozonoj @ gunet . georgetown . edu >'

# %%
for i in range(0,18650):
  if df['Email Type'][i]=='Safe Email':
    df['Email Type'][i]=1
  else:
    df['Email Type'][i]=0
# Out:
# <ipython-input-13-3d8a3d30548c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Email Type'][i]=1
# <ipython-input-13-3d8a3d30548c>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Email Type'][i]=0

# %%
df.head()
# Out:
#    Unnamed: 0                                         Email Text Email Type
# 0           0  re : 6 . 1100 , disc : uniformitarianism , re ...          1
# 1           1  the other side of * galicismos * * galicismo *...          1
# 2           2  re : equistar deal tickets are you still avail...          1
# 3           3  \nHello I am your hot lil horny toy.\n    I am...          0
# 4           4  software at incredibly low prices ( 86 % lower...          0

# %%
import nltk
nltk.download('punkt')
import spacy
from nltk.tokenize import sent_tokenize
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
nlp=spacy.load("en_core_web_sm")

# %%
doc=nlp(df['Email Text'][0])
print(doc)
# Out:
# re : 6 . 1100 , disc : uniformitarianism , re : 1086 ; sex / lang dick hudson 's observations on us use of 's on ' but not 'd aughter ' as a vocative are very thought-provoking , but i am not sure that it is fair to attribute this to " sons " being " treated like senior relatives " . for one thing , we do n't normally use ' brother ' in this way any more than we do 'd aughter ' , and it is hard to imagine a natural class comprising senior relatives and 's on ' but excluding ' brother ' . for another , there seem to me to be differences here . if i am not imagining a distinction that is not there , it seems to me that the senior relative terms are used in a wider variety of contexts , e . g . , calling out from a distance to get someone 's attention , and hence at the beginning of an utterance , whereas 's on ' seems more natural in utterances like ' yes , son ' , ' hand me that , son ' than in ones like ' son ! ' or ' son , help me ! ' ( although perhaps these latter ones are not com
# ...

# %%
for i in doc:
  print(i,i.lemma_)
# Out:
# re re
# : :
# 6 6
# . .
# 1100 1100
# , ,
# disc disc
# : :
# uniformitarianism uniformitarianism
# , ,
# re re
# : :
# 1086 1086
# ; ;
# sex sex
# / /
# lang lang
# dick dick
# hudson hudson
# 's 's
# observations observation
# on on
# us we
# use use
# of of
# 's be
# on on
# ' '
# but but
# not not
# 'd would
# aughter aughter
# ' '
# as as
# a a
# vocative vocative
# are be
# very very
# thought thought
# - -
# provoking provoking
# , ,
# but but
# i I
# am be
# not not
# sure sure
# that that
# it it
# is be
# fair fair
# to to
# attribute attribute
# this this
# to to
# " "
# sons son
# " "
# being be
# " "
# treated treat
# like like
# senior senior
# relatives relative
# " "
# . .
# for for
# one one
# thing thing
# , ,
# we we
# do do
# n't not
# normally normally
# use use
# ' '
# brother brother
# ' '
# in in
# this this
# way way
# any any
# more more
# than than
# we we
# do do
# 'd would
# aughter aughter
# ' '
# , ,
# and and
# it it
# is be
# hard hard
# to to
# ...

# %%
for i in doc:
  print(i,'|',i.pos_)
# Out:
# re | ADP
# : | PUNCT
# 6 | NUM
# . | NUM
# 1100 | NUM
# , | PUNCT
# disc | NOUN
# : | PUNCT
# uniformitarianism | NOUN
# , | PUNCT
# re | ADP
# : | PUNCT
# 1086 | NUM
# ; | PUNCT
# sex | NOUN
# / | SYM
# lang | PROPN
# dick | PROPN
# hudson | PROPN
# 's | PART
# observations | NOUN
# on | ADP
# us | PRON
# use | NOUN
# of | ADP
# 's | AUX
# on | ADP
# ' | PUNCT
# but | CCONJ
# not | PART
# 'd | AUX
# aughter | VERB
# ' | PUNCT
# as | ADP
# a | DET
# vocative | NOUN
# are | AUX
# very | ADV
# thought | ADJ
# - | PUNCT
# provoking | ADJ
# , | PUNCT
# but | CCONJ
# i | PRON
# am | AUX
# not | PART
# sure | ADJ
# that | SCONJ
# it | PRON
# is | AUX
# fair | ADJ
# to | PART
# attribute | VERB
# this | PRON
# to | ADP
# " | PUNCT
# sons | NOUN
# " | PUNCT
# being | AUX
# " | PUNCT
# treated | VERB
# like | ADP
# senior | ADJ
# relatives | NOUN
# " | PUNCT
# . | PUNCT
# for | ADP
# one | NUM
# thing | NOUN
# , | PUNCT
# we | PRON
# do | AUX
# n't | PART
# normally | ADV
# use | VERB
# ...

# %%
sentence = []
for w in doc:
  if w.text != 'n' and not w.is_stop and not w.is_punct and not   w.like_num:
    sentence.append(w.lemma_)
print(sentence)
# Out:
# ['disc', 'uniformitarianism', 'sex', 'lang', 'dick', 'hudson', 'observation', 'use', 'aughter', 'vocative', 'thought', 'provoking', 'sure', 'fair', 'attribute', 'son', 'treat', 'like', 'senior', 'relative', 'thing', 'normally', 'use', 'brother', 'way', 'aughter', 'hard', 'imagine', 'natural', 'class', 'comprise', 'senior', 'relative', 'exclude', 'brother', 'difference', 'imagine', 'distinction', 'senior', 'relative', 'term', 'wide', 'variety', 'contexts', 'e', 'g', 'call', 'distance', 'attention', 'beginning', 'utterance', 'natural', 'utterance', 'like', 'yes', 'son', 'hand', 'son', 'one', 'like', 'son', 'son', 'help', 'one', 'completely', 'impossible', 'alexis', 'mr']

# %%
df.rename(columns = {'Email Text':'Text'}, inplace = True)

# %%
df.rename(columns = {'Email Type':'Type'}, inplace = True)

# %%
df.head()
# Out:
#    Unnamed: 0                                               Text Type
# 0           0  re : 6 . 1100 , disc : uniformitarianism , re ...    1
# 1           1  the other side of * galicismos * * galicismo *...    1
# 2           2  re : equistar deal tickets are you still avail...    1
# 3           3  \nHello I am your hot lil horny toy.\n    I am...    0
# 4           4  software at incredibly low prices ( 86 % lower...    0

# %%
df.isna().sum()
# Out:
# Unnamed: 0     0
# Text          16
# Type           0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18650 entries, 0 to 18649
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  18650 non-null  int64
#  1   Text        18634 non-null  object
#  2   Type        18650 non-null  object
# dtypes: int64(1), object(2)
# memory usage: 437.2+ KB

# %%
import pandas as pd
import string
def remove_punctuation(text):
    if isinstance(text, str):
        punctuation_free = "".join([i for i in text if i not in string.punctuation])
        return punctuation_free
    else:
        return text
df['Text'] = df['Text'].apply(lambda x: remove_punctuation(x))
df.head()
# Out:
#    Unnamed: 0                                               Text Type
# 0           0  re  6  1100  disc  uniformitarianism  re  1086...    1
# 1           1  the other side of  galicismos   galicismo  is ...    1
# 2           2  re  equistar deal tickets are you still availa...    1
# 3           3  \nHello I am your hot lil horny toy\n    I am ...    0
# 4           4  software at incredibly low prices  86  lower  ...    0

# %%
def lowercase_text(text):
    if isinstance(text, str):
        return text.lower()
    else:
        return text
df['Text'] = df['Text'].apply(lambda x: lowercase_text(x))
df.head()
# Out:
#    Unnamed: 0                                               Text Type
# 0           0  re  6  1100  disc  uniformitarianism  re  1086...    1
# 1           1  the other side of  galicismos   galicismo  is ...    1
# 2           2  re  equistar deal tickets are you still availa...    1
# 3           3  \nhello i am your hot lil horny toy\n    i am ...    0
# 4           4  software at incredibly low prices  86  lower  ...    0

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, Bidirectional, LSTM, Dense, Dropout

model = Sequential()
model.add(Embedding(input_dim=input_dim, input_length=input_length, output_dim=embedding_dim))

model.add(Bidirectional(LSTM(units=your_lstm_units, return_sequences=True)))

model.add(Dense(units=your_dense_units, activation='relu'))

model.add(Dropout(rate=0.1))

model.add(Dense(units=1, activation='sigmoid'))

model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

model.summary()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-a0c8956bd62c> in <cell line: 6>()
#       4
#       5 model = Sequential()
# ----> 6 model.add(Embedding(input_dim=input_dim, input_length=input_length, output_dim=embedding_dim))
#       7
#       8 model.add(Bidirectional(LSTM(units=your_lstm_units, return_sequences=True)))
#
# NameError: name 'input_dim' is not defined

# %%
model.fit(X_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-27-86937c1966f0> in <cell line: 1>()
# ----> 1 clf.fit(X_train,y_train)
#
# /usr/local/lib/python3.10/dist-packages/sklearn/pipeline.py in fit(self, X, y, **fit_params)
#     399         """
#     400         fit_params_steps = self._check_fit_params(**fit_params)
# --> 401         Xt = self._fit(X, y, **fit_params_steps)
#     402         with _print_elapsed_time("Pipeline", self._log_message(len(self.steps) - 1)):
#     403             if self._final_estimator != "passthrough":
#
# /usr/local/lib/python3.10/dist-packages/sklearn/pipeline.py in _fit(self, X, y, **fit_params_steps)
#     357                 cloned_transformer = clone(transformer)
#     358             # Fit or load from cache the current transformer
# --> 359             X, fitted_transformer = fit_transform_one_cached(
# ...
